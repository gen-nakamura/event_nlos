# %%
import argparse
import torch
from torch.utils.data import DataLoader
import torch.optim as optim
import torch.nn as nn
from tqdm import tqdm
from model import MSTP  
from dataset import CustomDataset 
from earlystopping import EarlyStopping
from torch.utils.data import DataLoader, Subset
import wandb
import time
import os
import numpy as np
import matplotlib.pyplot as plt
os.environ['CUDA_LAUNCH_BLOCKING'] = "1"

model_path = "./model/model.pth"
TITLE = "BrandSilence"
batch_size = 6
epochs = 40


def plot_coordinates(pred, gt):
    """
    x, y座標の集合である(150, 2)の配列をプロットする関数

    Parameters:
    coordinates (numpy.ndarray): x, y座標の集合である配列
    """
    print(gt.shape)
    # 座標の取得
    x1 = pred[:, 0]
    y1 = pred[:, 1]
    x2 = gt[:, 0]
    y2 = gt[:, 1]

    # 散布図のプロット
    plt.scatter(x1, y1, label='prediction', color='red')
    plt.scatter(x2, y2, label='ground truth', color='gray')

    # グラフの設定
    plt.title('Scatter Plot of Coordinates')
    plt.xlabel('X-axis')
    plt.ylabel('Y-axis')
    plt.legend()
    plt.grid(True)

    # グラフの表示
    plt.show()



def train(model, train_loader, val_loader, optimizer, loss_function, device, num_epochs, project_name):
    early_stopping = EarlyStopping(patience=12, verbose=True, path=model_path)
    wandb.init(project="lip_reading", name=project_name)
    wandb.watch(loss_function, log="all")
    batch_num = batch_size

    for epoch in tqdm(range(num_epochs), desc="Epochs", ncols=100, position=0):
        count=0
        model.train()
        total_loss = 0
        for batch in tqdm(train_loader, desc=f"Epoch {epoch+1} Batches", ncols=100, position=0, leave=False):
            count +=1
            # print('batch')
            # ここでfor文回す
            event_low = batch['event_low'].to(device)
            event_high = batch['event_high'].to(device)
            labels = batch['label'].to(device)
            pred_plot = []
            # print('labels: ', labels)

            # assert event_low.shape == (batch_num, 30, 1, 480, 640), f"event_low shape is not what you expected: {event_low.shape}"
            # assert event_high.shape == (batch_num, 150, 1, 480, 640), f"event_high shape is not what you expected: {event_high.shape}"
            # assert labels.shape == (batch_num, 15, 2), f"label shape is not what you expected: {labels.shape}"
            for i in range(15):
                # print('start for')
                low_batch = event_low[:, i*2:(i+1)*2, :,  :, :]
                high_batch = event_high[:, i*10:(i+1)*10, :, :, :]
                label = labels[:, i:i+1].reshape((labels.size(0), 2))
                # print(f'label No.{i}: ', label)
                # assert low_batch.shape == (batch_num, 2, 1, 480, 640), f"event_low shape is not what you expected: {low_batch.shape}"
                # assert high_batch.shape == (batch_num, 10, 1, 480, 640), f"event_high shape is not what you expected: {high_batch.shape}"
                # assert label.shape == (batch_num, 1, 2), f"label shape is not what you expected: {label.shape}"
                # print('here')
                # for j in range(batch_num):
                #     low_batch = low_batch[j]
                #     high_batch = high_batch[j]
                #     label = label[j]
                outputs = model(low_batch, high_batch)
                loss = loss_function(outputs, label)
                pred_plot.append(outputs.to('cpu').detach().numpy())
                # if i < 5:
                    # for b in range(batch_size):
                    #     print('low-------------')
                    #     plt.imshow(low_batch[b][0][0].to('cpu'), cmap='gray')
                    #     plt.show()
                    #     plt.imshow(low_batch[b][1][0].to('cpu'), cmap='gray')
                    #     plt.show()
                    #     print('high------------')
                    #     plt.imshow(high_batch[b][0][0].to('cpu'), cmap='gray')
                    #     plt.show()
                    #     plt.imshow(high_batch[b][1][0].to('cpu'), cmap='gray')
                    #     plt.show()
                    # plot_coordinates(outputs.to('cpu').detach().numpy(), label.reshape((6, 2)).to('cpu').detach().numpy())

                # Backpropagation
                optimizer.zero_grad()
                loss.backward()
                optimizer.step()

                total_loss += loss.item()
            if epoch%5 == 0 and count == 1:
                pred_plot = np.array(pred_plot)
                for j in range(batch_size):
                    print(pred_plot[:, j])
                    print(labels[j])
                    assert labels[j].shape == (15, 2)
                    plot_coordinates(pred_plot[:, j], labels[j].to('cpu'))

        avg_loss = total_loss / len(train_loader) / 15 / batch_num
        # Call EarlyStopping
        early_stopping(avg_loss, model)
        if early_stopping.early_stop:
            print("Early stopping triggered")
            break
        # print(f'Epoch [{epoch+1}/{num_epochs}], Average Loss: {avg_loss:.4f}')
        wandb.log({"train_loss": avg_loss})

        

        # Validation phase
        model.eval()
        val_loss = 0
        with torch.no_grad():
            batch_count = 0
            for val_batch in tqdm(val_loader,desc=f"Valodation {epoch+1} Batches", ncols=100, position=2, leave=False): 
                batch_count += 1
                pred_plot = []
                # print('start val')
                event_low_val = val_batch['event_low'].to(device)
                event_high_val = val_batch['event_high'].to(device)
                labels_val = val_batch['label'].to(device)
                # assert event_low_val.shape == (batch_num, 30, 1, 480, 640), f"event_low shape is not what you expected: {event_low_val.shape}"
                # assert event_high_val.shape == (batch_num, 1, 150, 480, 640), f"event_high shape is not what you expected: {event_high_val.shape}"
                # assert labels_val.shape == (batch_num, 15, 2), f"label shape is not what you expected: {labels_val.shape}"
                for i in range(15):
                    low_batch = event_low_val[:, i*2:(i+1)*2, :, :]
                    high_batch = event_high_val[:, i*10:(i+1)*10, :, :]
                    label = labels_val[:, i:i+1].reshape((labels_val.size(0), 2))
                    # assert high_batch.shape == (batch_num, 10, 1, 480, 640), f"event_high shape is not what you expected: {high_batch.shape}"
                    # assert low_batch.shape == (batch_num, 2, 1, 480, 640), f"event_low shape is not what you expected: {low_batch.shape}"
                    # assert label.shape == (batch_num, 1, 2), f"label shape is not what you expected: {label.shape}"
                    # for j in range(batch_num):
                    #     low_batch = low_batch[j]
                    #     high_batch = high_batch[j]
                    #     label = label[j]
                    outputs = model(low_batch, high_batch)
                    # print('outputs shape: ', outputs.shape) # torch.size([6,2])
                    pred_plot.append(outputs.to('cpu').detach().numpy())
                    loss = loss_function(outputs, label)

                    val_loss += loss.item()
                    
                if batch_count == 1 and epoch%5 == 0:
                    pred_plot = np.array(pred_plot)
                    for j in range(batch_size):
                        print(pred_plot[:, j])
                        print(labels_val[j])
                        assert labels_val[j].shape == (15, 2)
                        plot_coordinates(pred_plot[:, j], labels_val[j].to('cpu'))

        avg_val_loss = val_loss / len(val_loader) / 15 / batch_num
        wandb.log({"val_loss": avg_val_loss})
        # print(f'Validation Loss: {avg_val_loss:.4f}')

        
    wandb.finish()

def test(model, test_loader, test_dataset,loss_function, device):
    model.eval()  # モデルを評価モードに設定
    total_loss = 0
    print('test')
    with torch.no_grad():  # 勾配計算を無効化
        start_time = time.time()  # Start the timer for the entire loop
        loop_count = 0  # Initialize loop counter

        for batch_count, batch in enumerate(test_loader):
            event_low = batch['event_low'].to(device)
            event_high = batch['event_high'].to(device)
            labels = batch['label'].to(device)
            pred_plot = []
            # assert event_low.shape == (batch_num, 30, 1, 480, 640), f"event_low shape is not what you expected: {event_low.shape}"
            # assert event_high.shape == (batch_num, 150, 1, 480, 640), f"event_high shape is not what you expected: {event_high.shape}"
            # assert labels.shape == (batch_num, 15, 2), f"label shape is not what you expected: {labels.shape}"

            for i in range(15):
                low_batch = event_low[:, i*2:(i+1)*2, :, :, :]
                high_batch = event_high[:, i*10:(i+1)*10, :, :, :]
                label = labels[:, i:i+1].reshape((labels.size(0), 2))
                # assert high_batch.shape == (batch_num, 10, 1, 480, 640), f"event_high shape is not what you expected: {high_batch.shape}"
                # assert low_batch.shape == (batch_num, 2, 1, 480, 640), f"event_low shape is not what you expected: {low_batch.shape}"
                # assert label.shape == (batch_num, 1, 2), f"label shape is not what you expected: {label.shape}"

                outputs = model(low_batch, high_batch)
                print('label: ', label)
                print('outputs: ', outputs)
                # print('output: ', outputs)
                # print('outputs shape: ', outputs.shape)
                pred_plot.append(outputs.to('cpu').detach().numpy())
                loss = loss_function(outputs, label)

                total_loss += loss.item()

            if batch_count == 1:
                pred_plot = np.array(pred_plot)
                for j in range(batch_size//2):
                    print(pred_plot[:, j])
                    print(labels[j])
                    assert labels[j].shape == (15, 2)
                    plot_coordinates(pred_plot[:, j], labels[j].to('cpu'))

    end_time = time.time()
    elapsed_time = end_time - start_time  # Calculate the elapsed time for the entire loop
    # avg_time_per_loop = elapsed_time / len(test_dataset) # Calculate the average time per loop
    print(f"Time taken for the entire loop: {elapsed_time:.4f} seconds")
    # print(f"Average time taken for one loop iteration: {avg_time_per_loop:.4f} seconds")
    # avg_loss = total_loss / len(test_loader) / 15  # 平均損失の計算
    # print(f'Test Loss: {avg_loss:.4f}')


def main():
    start_time = time.time()
    parser = argparse.ArgumentParser(description='Train the MSTP model')
    # parser.add_argument('--train_data_path', type=str, required=True, help='Path to the training data')
    parser.add_argument('--learning_rate', type=float, default=0.001, help='Learning rate')
    parser.add_argument('--num_epochs', type=int, default=10, help='Number of epochs')
    parser.add_argument('--batch_size', type=int, default=8, help='Batch size')
    parser.add_argument('--se', type=bool, default=False)
    parser.add_argument('--base_channel', type=int, default=64)
    parser.add_argument('--alpha', type=int, default=8)
    parser.add_argument('--beta', type=int, default=5)
    parser.add_argument('--t2s_mul', type=int, default=2)
    parser.add_argument('--wandb', type=str,  help='the name of wandb project')
    args = parser.parse_args(args=["--learning_rate", "0.001", "--num_epochs", f"{epochs}", "--batch_size", f"{batch_size}", "--wandb", "new_model_project_from_lip_reading"])
        

    input_path = '../Dataset/input_data/'
    target_path = '../Dataset/target_data/'
    print("Start loading dataset")
    dataset = CustomDataset(input_path, target_path, TITLE)

    # Calculate the indices for each subset
    total_size = 1000 # len(dataset)
    train_size = int(total_size * 0.7)
    val_size = int(total_size * 0.2)
    test_size = total_size - train_size - val_size

    # Split the dataset
    train_dataset = Subset(dataset, range(0, train_size))
    val_dataset = Subset(dataset, range(train_size, train_size + val_size))
    test_dataset = Subset(dataset, range(train_size + val_size, total_size))

    # Create DataLoaders for each set
    train_loader = DataLoader(train_dataset, batch_size=args.batch_size, shuffle=False)
    val_loader = DataLoader(val_dataset, batch_size=args.batch_size, shuffle=False)
    test_loader = DataLoader(test_dataset, batch_size=args.batch_size, shuffle=False)


    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model = MSTP(args).to(device)

    optimizer = optim.Adam(model.parameters(), lr=args.learning_rate)
    loss_function = nn.MSELoss()

    print("Start training")
    train(model, train_loader, val_loader, optimizer, loss_function, device, args.num_epochs, args.wandb)

    print("Training completed")
    model.load_state_dict(torch.load(model_path))
    print("Model Saved")

    print("Start Testing")

    test(model, test_loader, test_dataset,loss_function, device)

    end_time = time.time()
    elapsed_time = end_time - start_time 
    print(elapsed_time)

if __name__ == "__main__":
    main()
# Out:
# Start loading dataset
# Start training
# Tracking run with wandb version 0.16.2
# Run data is saved locally in <code>/home/gen0401/Documents/research/codes/event_nlos/lip_reading/wandb/run-20240124_040932-k8cjbzep</code>
# Syncing run <strong><a href='https://wandb.ai/gen0401/lip_reading/runs/k8cjbzep' target="_blank">new_model_project_from_lip_reading</a></strong> to <a href='https://wandb.ai/gen0401/lip_reading' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/gen0401/lip_reading' target="_blank">https://wandb.ai/gen0401/lip_reading</a>
#  View run at <a href='https://wandb.ai/gen0401/lip_reading/runs/k8cjbzep' target="_blank">https://wandb.ai/gen0401/lip_reading/runs/k8cjbzep</a>
# Epoch 1 Batches:   0%|                                                      | 0/117 [00:00<?, ?it/s]
# [[ 3.26436087e-02  2.26535723e-02]
#  [ 2.10757554e-01  1.86108351e-01]
# ...
